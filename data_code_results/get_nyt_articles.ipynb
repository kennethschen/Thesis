# %%
import sqlite3
import pickle

from collections import defaultdict as dd

from tqdm import tqdm
from time import sleep

import pandas as pd
import numpy as np

from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
# source: https://realpython.com/python-web-scraping-practical-introduction/
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
# database connection
conn = sqlite3.connect('stocks_data/sp500.db')
c = conn.cursor()

# get tickers and names
symbols = pd.read_sql("SELECT DISTINCT(symbol) FROM fact_table", con=conn)
dates = []
names = [] 
for i, row in symbols.iterrows():
    s = row['symbol']
    d = pd.read_sql("SELECT min(date), max(date) FROM fact_table WHERE symbol='{}'".format(s), con=conn)
    n = pd.read_sql("SELECT name, sector FROM dimension_table WHERE symbol='{}'".format(s), con=conn)
    dates.append(np.array(d)[0])
    names.append(np.array(n)[0])
ticker_df = pd.concat((symbols, pd.DataFrame(names, columns=['name','sector']), pd.DataFrame(dates, columns=['startdate', 'enddate'])), axis=1)

# %%
# one off, import tesla
ticker, name, industry, sd, ed = np.array(ticker_df.iloc[3])
tesla_df = pd.read_csv('stocks_data/tesla.csv')
tesla_df['date']
name = 'tesla'
textd = dd(dict)
visited = set()

# %%
# non-tesla companies
ticker, name, industry, sd, ed = np.array(ticker_df.iloc[3])
textd = dd(dict)
visited = set()
# name = name.replace('.', '')
# name = name.replace(',', '')
name = 'amazon.com inc' # 'amazon.com inc', 'apple inc', 'disney', 'goldman sachs', 'tesla'

# %%
# api key
key = 'tTGUbrG64HtoMQraJqLRgh4K1CNDqAxD'

# iterate over articles in the month and if found a match, go to url and scrape data
for year in np.arange(2010, 2019):
    for month in np.arange(1, 13):
        print(year, month)
        link = 'https://api.nytimes.com/svc/archive/v1/' + str(year) + '/' + str(month) + '.json?api-key=' + key
        metadata = pd.read_json(link)
        
        # iterate over each article
        for article in metadata['response']['docs']:
            for line in article['keywords']:

                # match and never came across the article in the month of interest
                if name.lower() in line['value'].lower() and article['web_url'] not in visited:                
                    visited.add(article['web_url'])
                    date = article['pub_date'].split('T')[0]
                    
                    print(article['web_url'])
                    print(article['keywords'])
                    
                    # scrape text
                    try:
                        doc = BeautifulSoup(simple_get(article['web_url']), 'html.parser')
                        paragraphs = doc.findAll('p', itemprop='articleBody')
                        if not paragraphs:
                            print('no articlebody')
                            paragraphs = doc.findAll('p', attrs={'class': 'story-body-text story-content'})
                        if not paragraphs:
                            print('no story body text')
                            paragraphs = doc.findAll('p', attrs={'class': 'css-1ygdjhk evys1bk0'})
                        if not paragraphs:
                            print('no css tag')
                        for i in range(len(paragraphs)):
                            textd[article['pub_date'].split('T')[0]][i] = paragraphs[i].get_text().lower()
                        # debug
                        print(textd[article['pub_date'].split('T')[0]] != {})
                    except Exception as exc:
                        print('traceback.format_exc()')
                        print(exc)
                    # next article
                    break
# Out:
# 2010 1
# https://gadgetwise.blogs.nytimes.com/2010/01/06/vudu-expands-its-service-to-more-tv-makers/
# [{'rank': '11', 'name': 'organizations', 'value': 'Vudu Inc'}, {'rank': '4', 'name': 'organizations', 'value': 'LG Electronics'}, {'rank': '10', 'name': 'organizations', 'value': 'Vizio Inc'}, {'rank': '3', 'name': 'organizations', 'value': 'Boxee Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'Netflix Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Roku'}, {'rank': '7', 'name': 'organizations', 'value': 'Roxio Inc'}, {'rank': '13', 'name': 'unknown', 'value': 'Netflix Inc|NFLX|NASDAQ'}, {'rank': '8', 'name': 'organizations', 'value': 'Sharp Corp'}, {'rank': '9', 'name': 'organizations', 'value': 'Toshiba Corporation'}, {'rank': '12', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}]
# True
# https://gadgetwise.blogs.nytimes.com/2010/01/07/plastic-logic-creates-the-paperless-briefcase/
# [{'rank': '4', 'name': 'organizations', 'value': 'Plastic Logic'}, {'rank': '3', 'name': 'organizations', 'value': 'Barnes & Noble Incorporated'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'unknown', 'value': 'Barnes & Noble Incorporated|BKS|NYSE'}]
# True
# https://www.nytimes.com/2010/01/10/business/10backpage-THETAXCLIMAT_LETTERS.html
# [{'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '1', 'name': 'organizations'}, {'value': 'Taxation', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Shopping and Retail', 'is_major': 'N', 'rank': '3', 'name': 'subject'}]
# no articlebody
# True
# https://www.nytimes.com/2010/01/17/magazine/17FOB-Medium-t.html
# [{'value': 'Computers and the Internet', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Reviews', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '3', 'name': 'organizations'}, {'value': 'Shopping and Retail', 'is_major': 'N', 'rank': '4', 'name': 'subject'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/01/20/amazon-cracks-open-the-kindle/
# [{'rank': '4', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Zagat Survey'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://bits.blogs.nytimes.com/2010/01/20/what-would-it-feel-like-to-hold-a-10-inch-apple-tablet/
# [{'rank': '11', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '4', 'name': 'subject', 'value': 'Computer Monitors'}, {'rank': '10', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '5', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '7', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '8', 'name': 'subject', 'value': 'Organic Light-Emitting Diodes'}, {'rank': '9', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '12', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/01/20/crowdflower-raises-five-million-to-boost-crowdsourcing/
# [{'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '3', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}]
# True
# https://www.nytimes.com/2010/01/21/technology/21reader.html
# [{'rank': '1', 'is_major': 'N', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '2', 'is_major': 'N', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '3', 'is_major': 'N', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '4', 'is_major': 'N', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '5', 'is_major': 'N', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '6', 'is_major': 'N', 'name': 'subject', 'value': 'Tablet Computers'}]
# no articlebody
# True
# https://www.nytimes.com/2010/01/23/books/23kindle.html
# [{'value': 'Amazon Kindle', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Writing and Writers', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'E-Commerce', 'is_major': 'N', 'rank': '6', 'name': 'subject'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/01/27/three-reasons-why-the-ipad-will-kill-amazons-kindle/
# [{'rank': '4', 'name': 'subject', 'value': 'iPhone'}, {'rank': '10', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '3', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '5', 'name': 'organizations', 'value': 'Adobe Systems Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '7', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '8', 'name': 'organizations', 'value': 'iTunes'}, {'rank': '9', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/01/27/three-reasons-the-ipad-wont-kill-amazons-kindle/
# [{'rank': '4', 'name': 'organizations', 'value': 'E Ink'}, {'rank': '3', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/01/27/live-blogging-the-apple-product-announcement/
# [{'rank': '11', 'name': 'subject', 'value': 'iPod'}, {'rank': '21', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '10', 'name': 'subject', 'value': 'iPhone'}, {'rank': '20', 'name': 'subject', 'value': 'Wireless Communications'}, {'rank': '23', 'name': 'organizations', 'value': 'Gameloft'}, {'rank': '22', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '16', 'name': 'subject', 'value': 'Shopping and Retail'}, {'rank': '26', 'name': 'organizations', 'value': 'New York Times'}, {'rank': '5', 'name': 'subject', 'value': 'Computer Monitors'}, {'rank': '15', 'name': 'subject', 'value': 'Recordings and Downloads (Video)'}, {'rank': '25', 'name': 'organizations', 'value': 'iTunes'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '24', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '14', 'name': 'subject', 'value': 'Newspapers'}, {'rank': '7', 'name': 'subject', 'value': 'Digital Audio Players'}, {'rank': '28', 'name': 'organizations', 'value': 'Pixar Animation Studios'}, {'rank': '13', 'name': 'subject', 'value': 'Movies'}, {'rank': '8', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '27', 'name': 'organizations', 'value': 'Penguin Group'}, {'rank': '9', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '12', 'name': 'subject', 'value': 'Laptop Computers'}, {'rank': '37', 'name': 'unknown', 'value': 'SONY Corporation|SNE|NYSE'}, {'rank': '4', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '29', 'name': 'organizations', 'value': 'SONY Corporation'}, {'rank': '19', 'name': 'subject', 'value': 'Tablet Computers'}, {'rank': '3', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '2', 'name': 'persons', 'value': 'Jobs, Steven P'}, {'rank': '18', 'name': 'subject', 'value': 'Software'}, {'rank': '17', 'name': 'subject', 'value': 'Smartphones'}, {'rank': '32', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '33', 'name': 'unknown', 'value': 'AT&T Corp|T|NYSE'}, {'rank': '30', 'name': 'organizations', 'value': 'YouTube.com'}, {'rank': '34', 'name': 'unknown', 'value': 'Barnes & Noble Incorporated|BKS|NYSE'}, {'rank': '35', 'name': 'unknown', 'value': 'Gameloft|GLOFF|other-OTC'}, {'rank': '31', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '36', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/01/29/amazon-pulls-macmillan-books-over-e-book-price-disagreement/
# [{'rank': '3', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://www.nytimes.com/2010/01/29/business/29amazon.html
# [{'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '1', 'name': 'organizations'}, {'value': 'Company Reports', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'E-Commerce', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Shopping and Retail', 'is_major': 'N', 'rank': '4', 'name': 'subject'}]
# no articlebody
# True
# https://www.nytimes.com/2010/01/30/technology/30amazon.html
# [{'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '1', 'name': 'organizations'}, {'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Books and Literature', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '4', 'name': 'subject'}, {'value': 'Amazon Kindle', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Farrar Straus & Giroux', 'is_major': 'N', 'rank': '6', 'name': 'organizations'}]
# no articlebody
# True
# 2010 2
# https://www.nytimes.com/2010/02/01/technology/companies/01amazonweb.html
# [{'value': 'Amazon Kindle', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Books and Literature', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Prices (Fares, Fees and Rates)', 'is_major': 'N', 'rank': '6', 'name': 'subject'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/02/02/macmillan-books-still-mostly-absent-from-amazoncom/
# [{'rank': '4', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Macmillan Publishers'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://bits.blogs.nytimes.com/2010/02/02/youtubes-take-from-movie-rentals-1070916/
# [{'rank': '11', 'name': 'unknown', 'value': 'Netflix Inc|NFLX|NASDAQ'}, {'rank': '4', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '10', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'iTunes'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Netflix Inc'}, {'rank': '7', 'name': 'organizations', 'value': 'YouTube.com'}, {'rank': '8', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '9', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/02/03/is-amazon-building-a-superkindle/
# [{'rank': '11', 'name': 'organizations', 'value': 'E Ink'}, {'rank': '4', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '10', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '5', 'name': 'subject', 'value': 'iPad'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'iPhone'}, {'rank': '7', 'name': 'subject', 'value': 'Mergers, Acquisitions and Divestitures'}, {'rank': '13', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '8', 'name': 'subject', 'value': 'Software'}, {'rank': '9', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '12', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}]
# True
# https://dealbook.nytimes.com/2010/02/03/amazon-is-said-to-buy-touch-screen-company/
# [{'rank': '11', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '4', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '10', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '5', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'iPad'}, {'rank': '14', 'name': 'unknown', 'value': 'Hewlett-Packard Co|HPQ|NYSE'}, {'rank': '7', 'name': 'subject', 'value': 'iPhone'}, {'rank': '13', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '8', 'name': 'subject', 'value': 'Mergers, Acquisitions and Divestitures'}, {'rank': '9', 'name': 'subject', 'value': 'Tablet Computers'}, {'rank': '12', 'name': 'organizations', 'value': 'Hewlett-Packard Co'}]
# True
# https://mediadecoder.blogs.nytimes.com/2010/02/04/buy-buttons-still-turned-off-on-amazon-for-some-macmillan-titles/
# [{'rank': '11', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '4', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '10', 'name': 'organizations', 'value': 'Macmillan Publishers'}, {'rank': '3', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '2', 'name': 'persons', 'value': 'Mantel, Hilary'}, {'rank': '5', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '7', 'name': 'subject', 'value': 'Royalties'}, {'rank': '8', 'name': 'subject', 'value': 'Writing and Writers'}, {'rank': '9', 'name': 'organizations', 'value': 'Amazon.com Inc'}]
# True
# https://www.nytimes.com/2010/02/04/technology/04amazon.html
# [{'rank': '1', 'is_major': 'N', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '2', 'is_major': 'N', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '3', 'is_major': 'N', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '4', 'is_major': 'N', 'name': 'organizations', 'value': 'Amazon.com Inc'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/02/05/macmillan-books-return-to-amazoncom/
# [{'rank': '4', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Macmillan Publishers'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://mediadecoder.blogs.nytimes.com/2010/02/08/nook-e-readers-will-be-available-at-barnes-noble-stores-beginning-wednesday/
# [{'rank': '4', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '5', 'name': 'organizations', 'value': 'Barnes & Noble Incorporated'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '7', 'name': 'unknown', 'value': 'Barnes & Noble Incorporated|BKS|NYSE'}]
# True
# https://bits.blogs.nytimes.com/2010/02/08/job-postings-hint-at-amazons-plans-for-the-kindle/
# [{'rank': '11', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '4', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '10', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '3', 'name': 'persons', 'value': 'Stone, Brad'}, {'rank': '2', 'name': 'persons', 'value': 'Bezos, Jeffrey P'}, {'rank': '17', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '16', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '5', 'name': 'subject', 'value': 'Color'}, {'rank': '15', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '14', 'name': 'organizations', 'value': 'Touchco'}, {'rank': '7', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '13', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '8', 'name': 'subject', 'value': 'Hiring and Promotion'}, {'rank': '9', 'name': 'subject', 'value': 'iPad'}, {'rank': '12', 'name': 'organizations', 'value': 'E Ink'}]
# True
# https://www.nytimes.com/2010/02/08/technology/internet/08price.html
# [{'value': 'E-Commerce', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Shopping and Retail', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Computers and the Internet', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Prices (Fares, Fees and Rates)', 'is_major': 'N', 'rank': '4', 'name': 'subject'}, {'value': 'Online Advertising', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '6', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '7', 'name': 'organizations'}, {'value': 'Buy.com Inc', 'is_major': 'N', 'rank': '8', 'name': 'organizations'}, {'value': 'Google Inc', 'is_major': 'N', 'rank': '9', 'name': 'organizations'}, {'value': 'Barnes & Noble Incorporated', 'is_major': 'N', 'rank': '10', 'name': 'organizations'}]
# no articlebody
# True
# https://www.nytimes.com/2010/02/08/business/media/08condense.html
# [{'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Pearson Plc', 'is_major': 'N', 'rank': '3', 'name': 'organizations'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Barnes & Noble Incorporated', 'is_major': 'N', 'rank': '5', 'name': 'organizations'}, {'value': 'Champy, James', 'is_major': 'N', 'rank': '6', 'name': 'persons'}, {'value': 'Hammer, Michael', 'is_major': 'N', 'rank': '7', 'name': 'persons'}, {'value': 'Amazon Kindle', 'is_major': 'N', 'rank': '8', 'name': 'subject'}]
# no articlebody
# True
# https://www.nytimes.com/2010/02/09/books/09google.html
# [{'value': 'Prices (Fares, Fees and Rates)', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Google Book Search', 'is_major': 'N', 'rank': '2', 'name': 'organizations'}, {'value': 'Books and Literature', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Google Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '5', 'name': 'organizations'}, {'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '6', 'name': 'subject'}, {'value': 'Macmillan Publishers', 'is_major': 'N', 'rank': '7', 'name': 'organizations'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/02/10/tech-talk-podcast-why-e-books-will-cost-more/
# [{'rank': '3', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://www.nytimes.com/2010/02/11/technology/11reader.html
# [{'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Prices (Fares, Fees and Rates)', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Books and Literature', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Shopping and Retail', 'is_major': 'N', 'rank': '4', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '5', 'name': 'organizations'}, {'value': 'Apple Inc', 'is_major': 'N', 'rank': '6', 'name': 'organizations'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/02/12/do-e-readers-cause-eye-strain/
# [{'rank': '11', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '4', 'name': 'subject', 'value': 'Computer Monitors'}, {'rank': '21', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '10', 'name': 'subject', 'value': 'iPad'}, {'rank': '19', 'name': 'organizations', 'value': 'University of North Carolina'}, {'rank': '20', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '2', 'name': 'persons', 'value': 'Hedge, Alan'}, {'rank': '18', 'name': 'organizations', 'value': 'Media Lab'}, {'rank': '17', 'name': 'organizations', 'value': 'Massachusetts Institute of Technology'}, {'rank': '22', 'name': 'unknown', 'value': 'Barnes & Noble Incorporated|BKS|NYSE'}, {'rank': '16', 'name': 'organizations', 'value': 'E Ink Corp'}, {'rank': '5', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '15', 'name': 'organizations', 'value': 'E Ink'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Ergonomics'}, {'rank': '14', 'name': 'organizations', 'value': 'Cornell University'}, {'rank': '7', 'name': 'subject', 'value': 'Eyes and Eyesight'}, {'rank': '13', 'name': 'organizations', 'value': 'consumer electronics'}, {'rank': '8', 'name': 'subject', 'value': 'Fatigue'}, {'rank': '9', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '12', 'name': 'organizations', 'value': 'Apple Inc'}]
# True
# https://bits.blogs.nytimes.com/2010/02/15/more-shoppers-go-online-hungry-for-deals/
# [{'rank': '4', 'name': 'organizations', 'value': 'Facebook.com'}, {'rank': '3', 'name': 'organizations', 'value': 'comScore, Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'HauteLook'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Twitter'}, {'rank': '7', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/02/18/bits-scan-thursdays-tech-news-roundup/
# [{'rank': '11', 'name': 'unknown', 'value': 'Eastman Kodak Co|EK|NYSE'}, {'rank': '4', 'name': 'organizations', 'value': 'Eastman Kodak Co'}, {'rank': '10', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'Facebook.com'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Fast Company'}, {'rank': '7', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '13', 'name': 'unknown', 'value': 'Research in Motion Ltd|RIMM|NASDAQ'}, {'rank': '8', 'name': 'organizations', 'value': 'Research in Motion Ltd'}, {'rank': '9', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '12', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}]
# True
# https://dealbook.nytimes.com/2010/02/18/turning-patents-into-invention-capital/
# [{'rank': '11', 'name': 'organizations', 'value': 'Oracle Corp'}, {'rank': '4', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '21', 'name': 'unknown', 'value': 'Microsoft Corp|MSFT|NASDAQ'}, {'rank': '10', 'name': 'organizations', 'value': 'Nokia Oyj'}, {'rank': '19', 'name': 'unknown', 'value': 'Intel Corp|INTC|NASDAQ'}, {'rank': '20', 'name': 'unknown', 'value': 'International Business Machines Corporation|IBM|NYSE'}, {'rank': '3', 'name': 'organizations', 'value': 'Adobe Systems Inc'}, {'rank': '23', 'name': 'unknown', 'value': 'Oracle Corp|ORCL|NASDAQ'}, {'rank': '2', 'name': 'persons', 'value': 'Myhrvold, Nathan'}, {'rank': '18', 'name': 'unknown', 'value': 'Hewlett-Packard Co|HPQ|NYSE'}, {'rank': '17', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '22', 'name': 'unknown', 'value': 'Nokia Oyj|NOK|NYSE'}, {'rank': '16', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '26', 'name': 'unknown', 'value': 'Verizon Communications|VZ|NYSE'}, {'rank': '5', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '15', 'name': 'unknown', 'value': 'Adobe Systems Inc|ADBE|NASDAQ'}, {'rank': '25', 'name': 'unknown', 'value': 'SONY Corporation|SNE|NYSE'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Hewlett-Packard Co'}, {'rank': '24', 'name': 'unknown', 'value': 'SAP AG|SAP|NYSE'}, {'rank': '14', 'name': 'organizations', 'value': 'Verizon Communications'}, {'rank': '7', 'name': 'organizations', 'value': 'Intel Corp'}, {'rank': '13', 'name': 'organizations', 'value': 'SONY Corporation'}, {'rank': '8', 'name': 'organizations', 'value': 'International Business Machines Corporation'}, {'rank': '9', 'name': 'organizations', 'value': 'Microsoft Corp'}, {'rank': '12', 'name': 'organizations', 'value': 'SAP AG'}]
# True
# https://www.nytimes.com/2010/02/21/business/21proto.html
# [{'rank': '1', 'is_major': 'N', 'name': 'organizations', 'value': 'Architectural Mailboxes'}, {'rank': '2', 'is_major': 'N', 'name': 'persons', 'value': 'Troyer, Vanessa'}, {'rank': '3', 'is_major': 'N', 'name': 'persons', 'value': 'Farentinos, Chris'}, {'rank': '4', 'is_major': 'N', 'name': 'subject', 'value': 'New Models, Design and Products'}, {'rank': '5', 'is_major': 'N', 'name': 'subject', 'value': 'Inventions and Patents'}, {'rank': '6', 'is_major': 'N', 'name': 'subject', 'value': 'Small Business'}, {'rank': '7', 'is_major': 'N', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '8', 'is_major': 'N', 'name': 'subject', 'value': 'E-Commerce'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/02/25/bits-scan-googles-accountability-and-nintendos-e-reader/
# [{'rank': '11', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '4', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '21', 'name': 'glocations', 'value': 'Italy'}, {'rank': '10', 'name': 'subject', 'value': 'Privacy'}, {'rank': '19', 'name': 'organizations', 'value': 'Nintendo Co Ltd'}, {'rank': '20', 'name': 'organizations', 'value': 'SONY Corporation'}, {'rank': '3', 'name': 'subject', 'value': 'Computer and Video Games'}, {'rank': '23', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '18', 'name': 'organizations', 'value': 'Microsoft Corp'}, {'rank': '17', 'name': 'organizations', 'value': 'LG Group'}, {'rank': '22', 'name': 'glocations', 'value': 'Wisconsin'}, {'rank': '16', 'name': 'organizations', 'value': 'LG Electronics'}, {'rank': '26', 'name': 'unknown', 'value': 'Microsoft Corp|MSFT|NASDAQ'}, {'rank': '5', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '15', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '25', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Extortion and Blackmail'}, {'rank': '24', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '14', 'name': 'organizations', 'value': 'Google Book Search'}, {'rank': '7', 'name': 'subject', 'value': 'Handheld Computers'}, {'rank': '28', 'name': 'unknown', 'value': 'SONY Corporation|SNE|NYSE'}, {'rank': '13', 'name': 'organizations', 'value': 'Facebook.com'}, {'rank': '8', 'name': 'subject', 'value': 'iPad'}, {'rank': '27', 'name': 'unknown', 'value': 'Nintendo Co Ltd|NTDOY|other-OTC'}, {'rank': '9', 'name': 'subject', 'value': 'New Models, Design and Products'}, {'rank': '12', 'name': 'organizations', 'value': 'Apple Inc'}]
# True
# https://bits.blogs.nytimes.com/2010/02/26/when-it-comes-to-content-amazons-kindle-wont-be-undersold/
# [{'rank': '11', 'name': 'organizations', 'value': 'E Ink'}, {'rank': '4', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '10', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '2', 'name': 'persons', 'value': 'Jobs, Steven P'}, {'rank': '5', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'iPad'}, {'rank': '14', 'name': 'unknown', 'value': 'SONY Corporation|SNE|NYSE'}, {'rank': '7', 'name': 'subject', 'value': 'Newspapers'}, {'rank': '13', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '8', 'name': 'subject', 'value': 'Shopping and Retail'}, {'rank': '9', 'name': 'subject', 'value': 'Software'}, {'rank': '12', 'name': 'organizations', 'value': 'SONY Corporation'}]
# True
# 2010 3
# https://gadgetwise.blogs.nytimes.com/2010/03/01/3d-tv-are-arriving-but-cant-play-3d-yet/
# [{'rank': '4', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Samsung Group'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}]
# True
# https://bits.blogs.nytimes.com/2010/03/05/a-former-book-designer-says-good-riddance-to-print/
# [{'rank': '11', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '4', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '10', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '3', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '2', 'name': 'subject', 'value': 'Blogs and Blogging (Internet)'}, {'rank': '5', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'iPad'}, {'rank': '7', 'name': 'subject', 'value': 'iPhone'}, {'rank': '8', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '9', 'name': 'organizations', 'value': 'Apple Inc'}]
# True
# https://bits.blogs.nytimes.com/2010/03/05/apple-ipad-arrives-in-stores-on-april-3/
# [{'rank': '11', 'name': 'subject', 'value': 'Wireless Communications'}, {'rank': '4', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '10', 'name': 'subject', 'value': 'Shopping and Retail'}, {'rank': '3', 'name': 'subject', 'value': 'Advertising and Marketing'}, {'rank': '2', 'name': 'persons', 'value': 'Jobs, Steven P'}, {'rank': '16', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '5', 'name': 'subject', 'value': 'Apple Store'}, {'rank': '15', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '14', 'name': 'glocations', 'value': 'United States'}, {'rank': '7', 'name': 'subject', 'value': 'iPad'}, {'rank': '13', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '8', 'name': 'subject', 'value': 'iPhone'}, {'rank': '9', 'name': 'subject', 'value': 'iPod'}, {'rank': '12', 'name': 'organizations', 'value': 'Amazon.com Inc'}]
# True
# https://dealbook.nytimes.com/2010/03/08/how-pandora-slipped-past-the-junkyard/
# [{'rank': '11', 'name': 'organizations', 'value': 'Samsung Group'}, {'rank': '4', 'name': 'organizations', 'value': 'Best Buy Company Incorporated'}, {'rank': '10', 'name': 'organizations', 'value': 'Salesforce.com Inc'}, {'rank': '19', 'name': 'unknown', 'value': 'Salesforce.com Inc|CRM|NYSE'}, {'rank': '3', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '2', 'name': 'persons', 'value': 'Westergren, Tim'}, {'rank': '18', 'name': 'unknown', 'value': 'Best Buy Company Incorporated|BBY|NYSE'}, {'rank': '17', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '16', 'name': 'organizations', 'value': 'Vizio Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'Ford Motor Co'}, {'rank': '15', 'name': 'organizations', 'value': 'Spotify'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'iTunes'}, {'rank': '14', 'name': 'organizations', 'value': 'SpiralFrog'}, {'rank': '7', 'name': 'organizations', 'value': 'MySpace.com'}, {'rank': '13', 'name': 'organizations', 'value': 'Sonos'}, {'rank': '8', 'name': 'organizations', 'value': 'Napster'}, {'rank': '9', 'name': 'organizations', 'value': 'Pandora.com'}, {'rank': '12', 'name': 'organizations', 'value': 'Saturn Division of General Motors Corp'}]
# True
# https://bits.blogs.nytimes.com/2010/03/09/what-were-reading-barbie-steve-jobs-and-carly-fiorina/
# [{'rank': '11', 'name': 'subject', 'value': 'Comic Books and Strips'}, {'rank': '4', 'name': 'persons', 'value': 'Jobs, Steven P'}, {'rank': '21', 'name': 'organizations', 'value': 'Microsoft Corp'}, {'rank': '10', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '29', 'name': 'unknown', 'value': 'Sun Microsystems Inc|SUNW|NASDAQ'}, {'rank': '19', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '20', 'name': 'organizations', 'value': 'Hewlett-Packard Co'}, {'rank': '3', 'name': 'persons', 'value': 'Gates, Bill'}, {'rank': '23', 'name': 'organizations', 'value': 'Twitter'}, {'rank': '2', 'name': 'persons', 'value': 'Fiorina, Carleton S'}, {'rank': '18', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '17', 'name': 'organizations', 'value': 'Adobe Systems Inc'}, {'rank': '22', 'name': 'organizations', 'value': 'Sun Microsystems Inc'}, {'rank': '16', 'name': 'subject', 'value': 'Shopping and Retail'}, {'rank': '26', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '5', 'name': 'persons', 'value': 'Packard, David'}, {'rank': '15', 'name': 'subject', 'value': 'iPhone'}, {'rank': '25', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'persons', 'value': 'Schwartz, Jonathan'}, {'rank': '24', 'name': 'unknown', 'value': 'Adobe Systems Inc|ADBE|NASDAQ'}, {'rank': '14', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '7', 'name': 'subject', 'value': 'Academy Awards (Oscars)'}, {'rank': '28', 'name': 'unknown', 'value': 'Microsoft Corp|MSFT|NASDAQ'}, {'rank': '13', 'name': 'subject', 'value': 'E-Commerce'}, {'rank': '8', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '27', 'name': 'unknown', 'value': 'Hewlett-Packard Co|HPQ|NYSE'}, {'rank': '9', 'name': 'subject', 'value': 'Barbie (Doll)'}, {'rank': '12', 'name': 'subject', 'value': 'Computers and the Internet'}]
# True
# https://bits.blogs.nytimes.com/2010/03/10/what-were-reading-what-youre-reading/
# [{'rank': '11', 'name': 'organizations', 'value': 'MySpace.com'}, {'rank': '4', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '10', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Computer Security'}, {'rank': '2', 'name': 'persons', 'value': "O'Brien, Conan"}, {'rank': '18', 'name': 'unknown', 'value': 'Yahoo Inc|YHOO|NASDAQ'}, {'rank': '17', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '16', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '5', 'name': 'subject', 'value': 'Crime and Criminals'}, {'rank': '15', 'name': 'organizations', 'value': 'YouTube.com'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Robberies and Thefts'}, {'rank': '14', 'name': 'organizations', 'value': 'Yahoo Inc'}, {'rank': '7', 'name': 'subject', 'value': 'Search Engines'}, {'rank': '13', 'name': 'organizations', 'value': 'Wired'}, {'rank': '8', 'name': 'subject', 'value': 'Social Networking (Internet)'}, {'rank': '9', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '12', 'name': 'organizations', 'value': 'Twitter'}]
# True
# https://bits.blogs.nytimes.com/2010/03/18/what-were-reading-hacked-cars-and-e-books-for-the-mac/
# [{'rank': '4', 'name': 'organizations', 'value': 'Facebook.com'}, {'rank': '10', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Twitter'}, {'rank': '7', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '8', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '9', 'name': 'unknown', 'value': 'AT&T Corp|T|NYSE'}]
# True
# https://www.nytimes.com/2010/03/18/technology/internet/18amazon.html
# [{'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '2', 'name': 'organizations'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Apple Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Books and Literature', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Amazon Kindle', 'is_major': 'N', 'rank': '6', 'name': 'subject'}, {'value': 'E-Commerce', 'is_major': 'N', 'rank': '7', 'name': 'subject'}]
# no articlebody
# True
# https://mediadecoder.blogs.nytimes.com/2010/03/22/perseus-signs-an-ebooks-deal-for-the-ipad/
# [{'rank': '11', 'name': 'organizations', 'value': 'Perseus Books'}, {'rank': '4', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '10', 'name': 'organizations', 'value': 'Macmillan Publishers'}, {'rank': '3', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '2', 'name': 'persons', 'value': 'Steinberger, David'}, {'rank': '5', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '7', 'name': 'subject', 'value': 'iPad'}, {'rank': '13', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '8', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '9', 'name': 'organizations', 'value': 'Grove/Atlantic'}, {'rank': '12', 'name': 'organizations', 'value': 'Zagat Survey'}]
# True
# https://www.nytimes.com/2010/03/23/business/media/23perseus.html
# [{'value': 'Apple Inc', 'is_major': 'N', 'rank': '1', 'name': 'organizations'}, {'value': 'Electronic Books and Readers', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'iPad', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Perseus Books', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Book Trade', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Workman Publishing', 'is_major': 'N', 'rank': '6', 'name': 'organizations'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '7', 'name': 'organizations'}, {'value': 'Steinberger, David', 'is_major': 'N', 'rank': '8', 'name': 'persons'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/03/24/e-book-sellers-face-a-battle-to-win-ipad-customers/
# [{'rank': '11', 'name': 'subject', 'value': 'Shopping and Retail'}, {'rank': '4', 'name': 'subject', 'value': 'Books and Literature'}, {'rank': '10', 'name': 'subject', 'value': 'iPhone'}, {'rank': '19', 'name': 'unknown', 'value': 'Barnes & Noble Incorporated|BKS|NYSE'}, {'rank': '3', 'name': 'subject', 'value': 'Book Trade'}, {'rank': '2', 'name': 'subject', 'value': 'Amazon Kindle'}, {'rank': '18', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}, {'rank': '17', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '16', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '5', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '15', 'name': 'organizations', 'value': 'Google Book Search'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Consumer Behavior'}, {'rank': '14', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '7', 'name': 'subject', 'value': 'Digital Audio Players'}, {'rank': '13', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '8', 'name': 'subject', 'value': 'Electronic Books and Readers'}, {'rank': '9', 'name': 'subject', 'value': 'iPad'}, {'rank': '12', 'name': 'subject', 'value': 'Software'}]
# True
# 2010 4
# https://dealbook.nytimes.com/2010/04/01/f-t-c-said-to-look-into-amazon-google-ties/
# [{'rank': '4', 'name': 'organizations', 'value': 'Federal Trade Commission'}, {'rank': '3', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '2', 'name': 'persons', 'value': 'Doerr, John'}, {'rank': '5', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '7', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}]
# True
# https://bits.blogs.nytimes.com/2010/04/01/f-t-c-is-said-to-have-looked-into-amazon-google-ties/
# [{'rank': '11', 'name': 'unknown', 'value': 'Intel Corp|INTC|NASDAQ'}, {'rank': '4', 'name': 'organizations', 'value': 'Federal Trade Commission'}, {'rank': '10', 'name': 'unknown', 'value': 'Google Inc|GOOG|NASDAQ'}, {'rank': '3', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '5', 'name': 'organizations', 'value': 'Google Book Search'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'organizations', 'value': 'Google Inc'}, {'rank': '7', 'name': 'organizations', 'value': 'Intel Corp'}, {'rank': '8', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '9', 'name': 'unknown', 'value': 'Apple Inc|AAPL|NASDAQ'}]
# True
# https://www.nytimes.com/2010/04/02/technology/02google.html
# [{'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '1', 'name': 'organizations'}, {'value': 'Doerr, John', 'is_major': 'N', 'rank': '2', 'name': 'persons'}, {'value': 'Federal Trade Commission', 'is_major': 'N', 'rank': '3', 'name': 'organizations'}, {'value': 'Google Inc', 'is_major': 'N', 'rank': '4', 'name': 'organizations'}, {'value': 'Suspensions, Dismissals and Resignations', 'is_major': 'N', 'rank': '5', 'name': 'subject'}]
# no articlebody
# True
# https://www.nytimes.com/2010/04/04/business/04digi.html
# [{'value': 'Music', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Philanthropy', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Social Networking (Internet)', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Computers and the Internet', 'is_major': 'N', 'rank': '4', 'name': 'subject'}, {'value': 'Grants (Corporate and Foundation)', 'is_major': 'N', 'rank': '5', 'name': 'subject'}, {'value': 'Kickstarter', 'is_major': 'N', 'rank': '6', 'name': 'organizations'}, {'value': 'MySpace.com', 'is_major': 'N', 'rank': '7', 'name': 'organizations'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '8', 'name': 'organizations'}]
# no articlebody
# True
# https://bits.blogs.nytimes.com/2010/04/09/more-fuzzy-e-book-numbers-this-time-from-apple/
# [{'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '2', 'name': 'organizations', 'value': 'Amazon.com Inc'}]
# True
# https://dealbook.nytimes.com/2010/04/13/for-tech-bidders-data-recovery-seems-alluring/
# [{'rank': '11', 'name': 'organizations', 'value': 'EMC Corporation'}, {'rank': '4', 'name': 'subject', 'value': 'Enterprise Computing'}, {'rank': '21', 'name': 'unknown', 'value': 'Hewlett-Packard Co|HPQ|NYSE'}, {'rank': '10', 'name': 'organizations', 'value': 'Double-Take Software, Incorporated'}, {'rank': '19', 'name': 'unknown', 'value': 'Double-Take Software, Incorporated|DBTK|NASDAQ'}, {'rank': '3', 'name': 'subject', 'value': 'Data Storage'}, {'rank': '20', 'name': 'unknown', 'value': 'EMC Corporation|EMC|NYSE'}, {'rank': '23', 'name': 'unknown', 'value': 'VMware Inc|VMW|NYSE'}, {'rank': '2', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '18', 'name': 'unknown', 'value': 'Dell Inc|DELL|NASDAQ'}, {'rank': '17', 'name': 'unknown', 'value': 'Citrix Systems Incorporated|CTXS|NASDAQ'}, {'rank': '22', 'name': 'unknown', 'value': 'Microsoft Corp|MSFT|NASDAQ'}, {'rank': '16', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '5', 'name': 'subject', 'value': 'Mergers, Acquisitions and Divestitures'}, {'rank': '15', 'name': 'organizations', 'value': 'VMware Inc'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Software'}, {'rank': '14', 'name': 'organizations', 'value': 'Microsoft Corp'}, {'rank': '7', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '13', 'name': 'organizations', 'value': 'Hitachi Data Systems'}, {'rank': '8', 'name': 'organizations', 'value': 'Citrix Systems Incorporated'}, {'rank': '9', 'name': 'organizations', 'value': 'Dell Inc'}, {'rank': '12', 'name': 'organizations', 'value': 'Hewlett-Packard Co'}]
# True
# https://www.nytimes.com/2010/04/19/technology/19cloud.html
# [{'value': 'Cloud Computing', 'is_major': 'N', 'rank': '1', 'name': 'subject'}, {'value': 'Computers and the Internet', 'is_major': 'N', 'rank': '2', 'name': 'subject'}, {'value': 'Enterprise Computing', 'is_major': 'N', 'rank': '3', 'name': 'subject'}, {'value': 'Data Centers', 'is_major': 'N', 'rank': '4', 'name': 'subject'}, {'value': 'Amazon.com Inc', 'is_major': 'N', 'rank': '5', 'name': 'organizations'}, {'value': 'Microsoft Corp', 'is_major': 'N', 'rank': '6', 'name': 'organizations'}, {'value': 'Google Inc', 'is_major': 'N', 'rank': '7', 'name': 'organizations'}, {'value': 'AT&T Corp', 'is_major': 'N', 'rank': '8', 'name': 'organizations'}]
# no articlebody
# True
# https://dealbook.nytimes.com/2010/04/20/another-view-peering-clearly-at-the-future/
# [{'rank': '11', 'name': 'subject', 'value': 'Start-ups'}, {'rank': '4', 'name': 'subject', 'value': 'Data Storage'}, {'rank': '21', 'name': 'unknown', 'value': 'Amazon.com Inc|AMZN|NASDAQ'}, {'rank': '10', 'name': 'subject', 'value': 'Software'}, {'rank': '19', 'name': 'organizations', 'value': 'VMware Inc'}, {'rank': '3', 'name': 'subject', 'value': 'Computers and the Internet'}, {'rank': '20', 'name': 'glocations', 'value': 'Wall Street (NYC)'}, {'rank': '23', 'name': 'unknown', 'value': 'Salesforce.com Inc|CRM|NYSE'}, {'rank': '2', 'name': 'subject', 'value': 'Cloud Computing'}, {'rank': '18', 'name': 'organizations', 'value': 'Seagate Technology'}, {'rank': '17', 'name': 'organizations', 'value': 'Salesforce.com Inc'}, {'rank': '22', 'name': 'unknown', 'value': 'Microsoft Corp|MSFT|NASDAQ'}, {'rank': '16', 'name': 'organizations', 'value': 'Microsoft Corp'}, {'rank': '5', 'name': 'subject', 'value': 'Enterprise Computing'}, {'rank': '15', 'name': 'organizations', 'value': 'Dell Inc'}, {'rank': '25', 'name': 'unknown', 'value': 'VMware Inc|VMW|NYSE'}, {'rank': '1', 'name': 'type_of_material', 'value': 'News'}, {'rank': '6', 'name': 'subject', 'value': 'Entrepreneurship'}, {'rank': '24', 'name': 'unknown', 'value': 'Seagate Technology|STX|NASDAQ'}, {'rank': '14', 'name': 'organizations', 'value': 'Apple Inc'}, {'rank': '7', 'name': 'subject', 'value': 'Music'}, {'rank': '13', 'name': 'organizations', 'value': 'Amazon.com Inc'}, {'rank': '8', 'name': 'subject', 'value': 'New Models, Design and Products'}, {'rank': '9', 'name': 'subject', 'value': 'Smartphones'}, {'rank': '12', 'name': 'subject', 'value': 'Venture Capital'}]
# True
# https://bits.blogs.nytimes.com/2010/04/22/what-danger-do-blippy-and-swipely-pose-to-amazon/
# ...
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/13/technology/tech-talent-apple-tech-giants-west-coast.html
# [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Foreign Workers', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'States (US)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Labor and Jobs', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Relocation of Business', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Colleges and Universities', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Visas', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'Alphabet Inc', 'rank': 8, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 9, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Google Inc', 'rank': 11, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/14/nyregion/google-nyc-amazon-offices.html
# [{'name': 'organizations', 'value': 'Google Inc', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Computers and the Internet', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate (Commercial)', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'Taconic Investment Partners', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Hoylman, Brad M', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Johnson, Corey', 'rank': 7, 'major': 'N'}, {'name': 'glocations', 'value': 'Chelsea (Manhattan, NY)', 'rank': 8, 'major': 'N'}, {'name': 'glocations', 'value': 'New York City', 'rank': 9, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/16/business/economy/nashville-birmingham-amazon.html
# [{'name': 'subject', 'value': 'Labor and Jobs', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Relocation of Business', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Area Planning and Renewal', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Urban Areas', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate (Commercial)', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Nashville (Tenn)', 'rank': 7, 'major': 'N'}, {'name': 'glocations', 'value': 'Birmingham (Ala)', 'rank': 8, 'major': 'N'}, {'name': 'glocations', 'value': 'Austin (Tex)', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Suburbs', 'rank': 10, 'major': 'N'}, {'name': 'subject', 'value': 'United States Economy', 'rank': 11, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/18/technology/france-tax-tech-companies.html
# [{'name': 'subject', 'value': 'Corporate Taxes', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Politics and Government', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Computers and the Internet', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Tax Shelters', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Online Advertising', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Social Media', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'E-Commerce', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Advertising and Marketing', 'rank': 8, 'major': 'N'}, {'name': 'subject', 'value': 'Antitrust Laws and Competition Issues', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Yellow Vests Movement', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 11, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 12, 'major': 'N'}, {'name': 'organizations', 'value': 'European Commission', 'rank': 13, 'major': 'N'}, {'name': 'organizations', 'value': 'European Union', 'rank': 14, 'major': 'N'}, {'name': 'organizations', 'value': 'Facebook Inc', 'rank': 15, 'major': 'N'}, {'name': 'organizations', 'value': 'Google Inc', 'rank': 16, 'major': 'N'}, {'name': 'organizations', 'value': 'Twitter', 'rank': 17, 'major': 'N'}, {'name': 'persons', 'value': 'Vestager, Margrethe', 'rank': 18, 'major': 'N'}, {'name': 'glocations', 'value': 'Europe', 'rank': 19, 'major': 'N'}, {'name': 'glocations', 'value': 'France', 'rank': 20, 'major': 'N'}, {'name': 'glocations', 'value': 'Ireland', 'rank': 21, 'major': 'N'}, {'name': 'glocations', 'value': 'Luxembourg', 'rank': 22, 'major': 'N'}, {'name': 'glocations', 'value': 'Spain', 'rank': 23, 'major': 'N'}, {'name': 'glocations', 'value': 'Great Britain', 'rank': 24, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/18/reader-center/amazon-hq2-new-york-data.html
# [{'name': 'subject', 'value': 'Relocation of Business', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Long Island City (Queens, NY)', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'New York City', 'rank': 4, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/19/technology/facebook-data-privacy-criticism.html
# [{'name': 'organizations', 'value': 'Facebook Inc', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Privacy', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Computers and the Internet', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Federal Trade Commission', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Social Media', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 8, 'major': 'N'}, {'name': 'organizations', 'value': 'Spotify', 'rank': 9, 'major': 'N'}, {'name': 'organizations', 'value': 'Tobii Technology', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Yandex NV', 'rank': 11, 'major': 'N'}, {'name': 'persons', 'value': 'Blumenthal, Richard', 'rank': 12, 'major': 'N'}, {'name': 'persons', 'value': 'Collins, Damian (1974- )', 'rank': 13, 'major': 'N'}, {'name': 'persons', 'value': 'Underwood, Barbara D', 'rank': 14, 'major': 'N'}, {'name': 'persons', 'value': 'Wyden, Ron', 'rank': 15, 'major': 'N'}, {'name': 'persons', 'value': 'Zuckerberg, Mark E', 'rank': 16, 'major': 'N'}, {'name': 'subject', 'value': 'Data-Mining and Database Marketing', 'rank': 17, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/21/technology/amazon-last-minute-gifts-shopping.html
# [{'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Delivery Services', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'E-Commerce', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Black Friday and Cyber Monday (Shopping)', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Shopping and Retail', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Christmas', 'rank': 6, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/21/business/dealbook/bigness-mergers-2018.html
# [{'name': 'subject', 'value': 'Mergers, Acquisitions and Divestitures', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'AT&T Inc', 'rank': 2, 'major': 'N'}, {'name': 'organizations', 'value': 'Aetna Inc', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'CVS Caremark Corporation', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Walt Disney Company', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Time Warner Inc', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'General Electric Company', 'rank': 8, 'major': 'N'}, {'name': 'organizations', 'value': 'United Technologies Corporation', 'rank': 9, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/23/business/media/worst-media-people-trump-fox-news-cbs-moonves.html
# [{'name': 'subject', 'value': 'News and News Media', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Two Thousand Eighteen', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Freedom of the Press', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'CBS Corporation', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Moonves, Leslie', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Dorsey, Jack', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Reid, Joy-Ann', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Rose, Charlie', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Sandberg, Sheryl K', 'rank': 9, 'major': 'N'}, {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Academy of Motion Picture Arts and Sciences', 'rank': 11, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 12, 'major': 'N'}, {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 13, 'major': 'N'}, {'name': 'persons', 'value': 'Brafman, Benjamin', 'rank': 14, 'major': 'N'}, {'name': 'organizations', 'value': 'Fox News Channel', 'rank': 15, 'major': 'N'}, {'name': 'organizations', 'value': 'Der Spiegel', 'rank': 16, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/24/opinion/facebook-technology-companies-2018.html
# [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Two Thousand Eighteen', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Science and Technology', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Facebook Inc', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Google Inc', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Corporations', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Zuckerberg, Mark E', 'rank': 9, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/23/books/paper-printers-holiday-sales-books-publishers.html
# [{'name': 'subject', 'value': 'Books and Literature', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Writing and Writers', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Book Trade and Publishing', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Halliday, Lisa', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Makkai, Rebecca', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Lepore, Jill', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Obama, Michelle', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Powers, Richard', 'rank': 9, 'major': 'N'}, {'name': 'persons', 'value': 'Woodward, Bob', 'rank': 10, 'major': 'N'}, {'name': 'creative_works', 'value': 'Asymmetry (Book)', 'rank': 11, 'major': 'N'}, {'name': 'creative_works', 'value': 'Becoming (Book)', 'rank': 12, 'major': 'N'}, {'name': 'creative_works', 'value': 'Fear: Trump in the White House (Book)', 'rank': 13, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Great Believers (Book)', 'rank': 14, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Overstory (Book)', 'rank': 15, 'major': 'N'}, {'name': 'creative_works', 'value': 'These Truths: A History of the United States (Book)', 'rank': 16, 'major': 'N'}, {'name': 'creative_works', 'value': 'Washington Black: A Novel (Book)', 'rank': 17, 'major': 'N'}, {'name': 'subject', 'value': 'Shortages', 'rank': 18, 'major': 'N'}, {'name': 'subject', 'value': 'Paper and Pulp', 'rank': 19, 'major': 'N'}, {'name': 'organizations', 'value': 'Barnes & Noble Inc', 'rank': 20, 'major': 'N'}, {'name': 'organizations', 'value': 'Norton, W W, & Co', 'rank': 21, 'major': 'N'}, {'name': 'organizations', 'value': 'Penguin Random House', 'rank': 22, 'major': 'N'}, {'name': 'organizations', 'value': 'LSC Communications', 'rank': 23, 'major': 'N'}, {'name': 'organizations', 'value': 'Quad/Graphics Inc', 'rank': 24, 'major': 'N'}, {'name': 'organizations', 'value': 'Edward Brothers Malloy', 'rank': 25, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/27/realestate/interest-in-court-square-condo-spikes-thanks-to-amazon.html
# [{'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 1, 'major': 'N'}, {'name': 'glocations', 'value': 'Long Island City (Queens, NY)', 'rank': 2, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 3, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/27/world/americas/amazon-brazil-expansion.html
# [{'name': 'glocations', 'value': 'Brazil', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'E-Commerce', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Shopping and Retail', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'International Trade and World Market', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Mercadolibre Inc', 'rank': 6, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/27/nyregion/amazon-queens-real-estate.html
# [{'name': 'subject', 'value': 'Real Estate Brokers', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 2, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'Long Island City (Queens, NY)', 'rank': 4, 'major': 'N'}]
# no articlebody
# no story body text
# True
# https://www.nytimes.com/2018/12/29/opinion/tech-2018-trends-2019-predictions.html
# [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Industrial Espionage', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'United States Politics and Government', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Social Media', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Cyberattacks and Hackers', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Espionage and Intelligence Services', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Privacy', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Russian Interference in 2016 US Elections and Ties to Trump Associates', 'rank': 8, 'major': 'N'}, {'name': 'subject', 'value': 'Computer Security', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'United States Defense and Military Forces', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 11, 'major': 'N'}, {'name': 'organizations', 'value': 'Facebook Inc', 'rank': 12, 'major': 'N'}, {'name': 'organizations', 'value': 'Google Inc', 'rank': 13, 'major': 'N'}, {'name': 'organizations', 'value': 'Google+', 'rank': 14, 'major': 'N'}, {'name': 'organizations', 'value': 'Salesforce.com Inc', 'rank': 15, 'major': 'N'}, {'name': 'glocations', 'value': 'Silicon Valley (Calif)', 'rank': 16, 'major': 'N'}]
# no articlebody
# no story body text
# True

# %%
# write to file with pickle (as binary)
name='amazon' # amazon, apple, disney, goldman_sachs, tesla
f = open('news_data/' + str(name) + '.pickle', 'wb')
newData = pickle.dump(textd, f)
# f.write(newData)
f.close()

# %%
# open file with pickle (as binary)
name='amazon'
f = open('news_data/' + str(name) + '.pickle', 'rb')
raw_articles = pickle.load(f)
f.close()
